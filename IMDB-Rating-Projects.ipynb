# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.__version__
# Out:
# '1.26.4'

# %%
movies = pd.read_csv(r"E:\Datasets\Movie-Rating.csv")

# %%
movies
# Out:
#                       Film      Genre  CriticRatings  AudienceRatings  \
# 0    (500) Days of Summer      Comedy             87               81
# 1              10,000 B.C.  Adventure              9               44
# 2               12 Rounds      Action             30               52
# 3                127 Hours  Adventure             93               84
# 4                17 Again      Comedy             55               70
# ..                     ...        ...            ...              ...
# 554          Your Highness     Comedy             26               36
# 555        Youth in Revolt     Comedy             68               52
# 556                 Zodiac   Thriller             89               73
# 557            Zombieland      Action             90               87
# 558              Zookeeper     Comedy             14               42
#
#      BudgetMillions  Year
# 0                 8   2009
# 1               105   2008
# 2                20   2009
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movies)
# Out:
# 559

# %%
np.__version__
# Out:
# '1.26.4'

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRatings', 'AudienceRatings', 'BudgetMillions',
#        'Year '],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Genre            559 non-null    object
#  2   CriticRatings    559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRatings  AudienceRatings  \
# 0  (500) Days of Summer      Comedy             87               81
# 1            10,000 B.C.  Adventure              9               44
# 2             12 Rounds      Action             30               52
# 3              127 Hours  Adventure             93               84
# 4              17 Again      Comedy             55               70
#
#    BudgetMillions  Year
# 0               8   2009
# 1             105   2008
# 2              20   2009
# 3              18   2010
# 4              20   2009

# %%
movies.tail()
# Out:
#                 Film     Genre  CriticRatings  AudienceRatings  \
# 554    Your Highness    Comedy             26               36
# 555  Youth in Revolt    Comedy             68               52
# 556           Zodiac  Thriller             89               73
# 557      Zombieland     Action             90               87
# 558        Zookeeper    Comedy             14               42
#
#      BudgetMillions  Year
# 554              50   2011
# 555              18   2009
# 556              65   2007
# 557              24   2009
# 558              80   2011

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Genre = movies.Genre.astype('category')

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# !pip install seaborn
# Out:
# ...
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\suraj\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\suraj\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\suraj\anaconda3\Lib\site-packages)

# %%
import seaborn as sns
# %matplotlib inline
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# * basically joint plot is a scatter plot & it find the relation b/w audiene & critics
# * also if you look up you can find the uniform distribution (critics)and normal distriution (audience)

# %%
# Audience rating is more dominant then critics rating
# Based on this we find out as most people are most liklihood to watch audience rating & less likely to wathc critics rating
# let me explain the excel - if you filter audience rating & critic rating. critic rating has very low values compare to audience rating

# %%
sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')
plt.show()

# %% [markdown]
# Prakas sir -9353157658

# %%
# Out:
# Python 3.12.7

# %%
# Draw the plot by using two variable(bivariate)
sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',kind = 'kde')
plt.show()

# %%
sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',kind = 'hex')
plt.show()

# %%
sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',kind = 'hist')
plt.show()

# %%
sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',kind = 'reg')
plt.show()

# %%
sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating',kind = 'resid')
plt.show()

# %%
sns.distplot(movies.AudienceRating) # Normal Distrubtion
plt.show()

# %%
sns.distplot(movies.CriticRating) # Normal Distrubtion
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(movies.CriticRating,bins = 10) # Normal Distrubtion
plt.show()

# %%
plt.hist(movies.AudienceRating,bins = 15)
plt.show()

# %%
sns.set_style('white')
plt.hist(movies.AudienceRating, bins = 20)
plt.show()

# %%
plt.hist(movies.CriticRating,bins = 20)
plt.show()

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)
plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
# Below plots are stacked histogram becuase overlaped

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20,label = 'Action')
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20,label = 'Thriller')
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20,label = 'Drama')

plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,
         movies[movies.Genre == 'Thriller'].BudgetMillions,
         movies[movies.Genre == 'Drama'].BudgetMillions,
         movies[movies.Genre == 'Comedy'].BudgetMillions],
        bins = 20,stacked = True)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
sns.lmplot(data = movies,x = 'CriticRating', y = 'AudienceRating',fit_reg = True)
plt.show()

# %%
sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating',fit_reg = False)
plt.show()

# %%
sns.lmplot(data = movies,x = 'CriticRating',y = 'AudienceRating',fit_reg = False,hue = 'Genre')
plt.show()

# %%
sns.lmplot(data = movies, x = 'CriticRating', y = 'AudienceRating',hue = 'Genre',fit_reg = True)
plt.show()

# %%
# Kernal Density Estimate plot ( KDE PLOT) 
# how can i visulize audience rating & critics rating . using scatterplot

# %%
# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings

sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',)
plt.show()

# %%
sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',shade = True,shade_lowest = False,cmap = 'Reds')
plt.show()

# %%
sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',shade = True,shade_lowest = False,cmap = 'icefire')
plt.show()

# %%
sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',shade = False,shade_lowest = False,cmap = 'Greens_r')
plt.show()

# %%
sns.set_style('dark')
sns.kdeplot(data = movies,x = 'BudgetMillions', y = 'AudienceRating',shade_lowest = False,cmap = 'Greens_r')
plt.show()

# %%
sns.set_style('dark')
sns.kdeplot(data = movies,x = 'BudgetMillions', y = 'AudienceRating')
plt.show()

# %%
sns.kdeplot(data = movies,x = 'BudgetMillions',y = 'CriticRating')
plt.show()

# %% [markdown]
# # Subplots

# %%
sns.set_style('white')
plt.subplots(3,3,figsize = (20,10))
plt.show()

# %%
f, axes = plt.subplots(1,2,figsize = (12,6))
sns.kdeplot(data = movies,x = 'BudgetMillions',y = 'AudienceRating',ax = axes[0])
sns.kdeplot(data = movies,x = 'BudgetMillions',y = 'CriticRating',ax = axes[1])
plt.show()

# %%
axes
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='CriticRating'>],
#       dtype=object)

# %% [markdown]
# # Box plots

# %%
sns.boxplot(data = movies, x = 'Genre',y = 'CriticRating')
plt.show()

# %%
sns.violinplot(data = movies, x = 'Genre',y = 'CriticRating')
plt.show()

# %%
sns.violinplot(data = movies, x = 'Genre',y = 'AudienceRating')
plt.show()

# %%
sns.boxplot(data = movies[movies.Genre == 'Drama'], x = 'Year', y = 'AudienceRating')
plt.show()

# %%
sns.boxplot(data = movies[movies.Genre == 'Horror'], x = 'Year', y = 'AudienceRating')
plt.show()

# %%
# Multivariate analysis - heatmap,pairplot and facetplot

# %% [markdown]
# # Facetgrid

# %%
sns.FacetGrid(data = movies,row = 'Genre',col = 'Year',hue = 'Genre')
plt.show()

# %%
plt.scatter(movies.CriticRating,movies.AudienceRating)
plt.show()

# %%
f = sns.FacetGrid(data = movies,row = 'Genre',col = 'Year',hue = 'Genre')
f = f.map(plt.scatter,'CriticRating','AudienceRating')
plt.show()

# %%
f = sns.FacetGrid(data = movies,row = 'Genre',col = 'Year',hue = 'Genre')
f = f.map(plt.hist,'BudgetMillions')
plt.show()

# %%
f = sns.FacetGrid(data = movies,row = 'Genre',col = 'Year',hue = 'Genre')
f = f.map(plt.plot,'BudgetMillions')
plt.show()

# %%
f = sns.FacetGrid(data = movies,row = 'Genre',col = 'Year',hue = 'Genre')
kws = dict(s = 50, linewidth = 0.5, edgecolor = 'black')
f = f.map(plt.scatter,'CriticRating','AudienceRating',**kws)
plt.show()

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize = (10,10))

k1 = sns.kdeplot(data = movies,x = 'BudgetMillions',y = 'AudienceRating',ax=axes[0,0])
k2 = sns.kdeplot(data = movies,x = 'BudgetMillions',y = 'CriticRating',ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(data = movies,x = 'CriticRating',y = 'AudienceRating',cmap='Reds',ax = axes[1,1])

plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)
